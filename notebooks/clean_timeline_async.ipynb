# %%
# %load_ext blackcellmagic

# %%
import tweepy
import re
from decouple import config
import json
import requests
import sys

TWITTER_AUTH = tweepy.OAuthHandler(config('TWITTER_CONSUMER_KEY'),config('TWITTER_CONSUMER_SECRET'))

TWITTER_AUTH.set_access_token(config('TWITTER_ACCESS_TOKEN'),config('TWITTER_ACCESS_TOKEN_SECRET'))

TWITTER = tweepy.API(TWITTER_AUTH)

# %%
TWITTER_ACCESS_TOKEN =config('TWITTER_ACCESS_TOKEN')
TWITTER_ACCESS_TOKEN_SECRET =config('TWITTER_ACCESS_TOKEN_SECRET')

# %%
import tweepy
import re
from decouple import config
import json
import requests
import sys
import asyncio
from concurrent.futures import ThreadPoolExecutor
import nest_asyncio
from itertools import zip_longest

nest_asyncio.apply()


def process_request(request):
    """ Responds to a GET request with "Hello world!". Forbids a PUT request.
    Args:
        request (flask.Request): The request object.
        <http://flask.pocoo.org/docs/1.0/api/#flask.Request>
    Returns:
        The response text, or any set of values that can be turned into a
         Response object using `make_response`
        <http://flask.pocoo.org/docs/1.0/api/#flask.Flask.make_response>.
    """
    from flask import abort

    content_type = request.headers["content-type"]
    request_json = request.get_json(silent=True)
    request_args = request.args

    if content_type == "application/json":
        request_json = request.get_json(silent=True)
        # TWITTER_ACCESS_TOKEN check/set/error
        if request_json and "TWITTER_ACCESS_TOKEN" in request_json:
            TWITTER_ACCESS_TOKEN = request_json["TWITTER_ACCESS_TOKEN"]
        else:
            raise ValueError("Missing a 'TWITTER_ACCESS_TOKEN'")
        # TWITTER_ACCESS_TOKEN_SECRET check/set/error
        if request_json and "TWITTER_ACCESS_TOKEN_SECRET" in request_json:
            TWITTER_ACCESS_TOKEN_SECRET = request_json["TWITTER_ACCESS_TOKEN_SECRET"]
        else:
            raise ValueError("Missing a 'TWITTER_ACCESS_TOKEN_SECRET'")

        if request_json and "num_pages" in request_json:
            num_pages = request_json["num_pages"]
        else:
            num_pages = 1

        if request_json and "toxicity_threshold" in request_json:
            toxicity_threshold = request_json["toxicity_threshold"]
        else:
            toxicity_threshold = 0.0

        # Call the function for the POST request.
        if request.method == "POST":
            establish_twitter_credentials(
                TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET
            )

            return execute_async_index_event_loop(num_pages, toxicity_threshold)
    else:
        return abort(405)


def establish_twitter_credentials(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET):
    """establish Twitter as as global. No need to pass it everytime.
    """
    twitter_auth = tweepy.OAuthHandler(
        config("TWITTER_CONSUMER_KEY"), config("TWITTER_CONSUMER_SECRET")
    )
    access_token = TWITTER_ACCESS_TOKEN
    access_token_secret = TWITTER_ACCESS_TOKEN_SECRET
    twitter_auth.set_access_token(access_token, access_token_secret)
    global TWITTER
    TWITTER = tweepy.API(twitter_auth)


def execute_async_index_event_loop(num_pages, toxicity_threshold):
    """
    This function does something analogous to compiling the get_data_asynchronously function,
    Then it executes loop.
    1. Call the get_data_function
    2. Get the event_loop
    3. Run the tasks (Much easier to understand in python 3.7, "ensure_future" was changed to "create_task")
    4. Edge_list and top_interactions will be passed to the next functions
    """
    final_output = []
    mentions_timeline = get_mentions(final_output, num_pages)
    future = asyncio.ensure_future(
        get_index_data_asynchronous(final_output, num_pages, mentions_timeline)
    )
    loop = asyncio.get_event_loop()
    loop.run_until_complete(future)
    # filter tweets for toxicity, removing None's
    final_output = [
        filter_tweets(tweet, toxicity_threshold)
        for tweet in final_output
        if filter_tweets(tweet, toxicity_threshold) is not None
    ]
    return json.dumps(final_output)


def get_mentions(final_output, num_pages):
    """
    Get tweets in which the user is mentioned.
    """
    try:
        mentions_timeline = TWITTER.mentions_timeline(
            count=32 * num_pages, tweet_mode="extended", exclude_rts=False
        )

        # create list of lists where sublists = 32 for BERT model, removing None's
        z = list(grouper(mentions_timeline, 32))
        mentions_timeline = [[i for i in subz if i is not None] for subz in z]
        return mentions_timeline

    except tweepy.TweepError:
        print("tweepy.TweepError")

    except:
        e = sys.exc_info()[0]
        print("get_metions: Error: %s" % e)


async def get_index_data_asynchronous(final_output, num_pages, mentions_timeline):
    """
    1. Establish an executor and number of workers
    2. Establish the session
    3. Establish the event loop
    4. Create the tasks. Add two lists together. (because as I understand appending adds the list inside of a list.)
        4a. tasks are created by list comprenhensions
    5. Gather tasks.
    """
    with ThreadPoolExecutor(max_workers=20) as executor:
        with requests.Session() as session:
            loop = asyncio.get_event_loop()
            tasks = [
                loop.run_in_executor(
                    executor, clean_timeline, *(session, final_output, page)
                )
                for page in range(num_pages)
            ] + [
                loop.run_in_executor(
                    executor, clean_mentions, *(session, sub_timeline, final_output)
                )
                for sub_timeline in mentions_timeline
            ]
            for response in await asyncio.gather(*tasks):
                pass


def clean_timeline(session, final_output, page):
    """
    1. Retrieve 32 tweets
    2. Prepare the tweet for BERT
    3. Execute the BERT analysis
    4. Add the results to the final_output
    """
    try:
        home_timeline = TWITTER.home_timeline(
            count=32,
            tweet_mode="extended",
            exlude_rts=False,
            exclude_replies=False,
            page=page,
        )
        tweet_text_list = [process_tweet(h.full_text) for h in home_timeline]
        final_output += bert_request(tweet_text_list, home_timeline)

    except tweepy.TweepError:
        print("clean_timeline: tweepy.TweepError")

    except:
        e = sys.exc_info()[0]
        print("clean_timeline: Error: %s" % e)


def clean_mentions(session, sub_timeline, final_output):
    """
    Puts together the new BERT results with the final_output
    """
    tweet_text_list = [process_tweet(h.full_text) for h in sub_timeline]
    final_output += bert_request(tweet_text_list, sub_timeline)


def process_tweet(tweet_text):
    """
    Prepare the tweet for the BERT model.
    """
    # strip username
    tweet = re.sub(
        r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))@([A-Za-z]+[A-Za-z0-9-_]+)", "", tweet_text
    )
    # strip newlines and unicode characters that aren't formatted
    tweet = re.sub(r"\n|&gt;|RT :", "", tweet)
    # strip twitter urls from tweets
    tweet = re.sub(
        r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))https://t.co/([A-Za-z0-9-_,\']+)", "", tweet
    )
    # Remove emojis
    RE_EMOJI = re.compile("[\U00010000-\U0010ffff]", flags=re.UNICODE)
    tweet = RE_EMOJI.sub(r"", tweet)
    # remove whitespace
    tweet = tweet.strip()
    # make api request for toxicity analysis

    tweet_info = {"tweet": tweet}
    return tweet_info


def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    # grouper('ABCDEFG', 3, 'x') --> ABC DEF Gxx
    args = [iter(iterable)] * n
    return zip_longest(fillvalue=fillvalue, *args)


def bert_request(tweet_text_list, sub_timeline):
    """
    1. Extract just the tweet from the sub_timeline
    2. Pass the list of tweets to the BERT function.
    3. Zip the original sub_timeline passed to the function
    4. Put the zip object into a dictionary
    """
    tweet_list = [tweet["tweet"] for tweet in tweet_text_list]
    data = {"description": tweet_list, "max_seq_length": 32}
    headers = {"Content-type": "application/json", "cache-control": "no-cache"}
    data = json.dumps(data)
    results = requests.post(
        "http://35.232.246.186:5000/", data=data, headers=headers
    ).json()["results"]
    # results is a list comprehension of zipping tweet & bert_result lists
    # and making two dictionary key,values out of each.
    output = [
        {"tweet": t._json, "bert_result": r} for t, r in zip(sub_timeline, results)
    ]
    return output


def filter_tweets(tweet, toxicity_threshold):
    """
    Used with a list comprehension to return only a list of toxic tweets
    """
    if (
        (tweet["bert_result"]["identity_hate"] >= toxicity_threshold)
        | (tweet["bert_result"]["insult"] >= toxicity_threshold)
        | (tweet["bert_result"]["obscene"] >= toxicity_threshold)
        | (tweet["bert_result"]["severe_toxic"] >= toxicity_threshold)
        | (tweet["bert_result"]["threat"] >= toxicity_threshold)
        | (tweet["bert_result"]["toxic"] >= toxicity_threshold)
    ):
        return tweet
    else:
        pass

# %%
# %%time
f = execute_async_index_event_loop(1,.5)
# Out:
# Wall time: 7.15 s

# %%
f = json.loads(f)

# %%
# Out:
# []

# %% [markdown]
# # tests

# %%
page=1
home_timeline = TWITTER.home_timeline(
            count=32,
            tweet_mode="extended",
            exlude_rts=False,
            exclude_replies=False,
            page=page,
        )
tweet_text_list = [process_tweet(h.full_text) for h in sub_timeline]
final_output += bert_request(tweet_text_list, sub_timeline)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-fd76625a09f5> in <module>
#       7             page=page,
#       8         )
# ----> 9 tweet_text_list = [process_tweet(h.full_text) for h in sub_timeline]
#      10 final_output += bert_request(tweet_text_list, sub_timeline)
#
# NameError: name 'sub_timeline' is not defined

# %%
# Out:
# [{'tweet': {'created_at': 'Sat May 18 21:54:02 +0000 2019',
#    'id': 1129867769124536320,
#    'id_str': '1129867769124536320',
#    'full_text': '@crawfteevee Of lecture yes, but the rest can’t be asynchronous',
#    'truncated': False,
#    'display_text_range': [13, 63],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'crawfteevee',
#       'name': 'crawford',
#       'id': 954460588977086465,
#       'id_str': '954460588977086465',
#       'indices': [0, 12]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1129864559991377923,
#    'in_reply_to_status_id_str': '1129864559991377923',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 221838349,
#     'id_str': '221838349',
#     'name': 'Austen Allred',
#     'screen_name': 'Austen',
#     'location': 'San Francisco, CA',
#     'description': "CEO @LambdaSchool (YC S17): A CS education that's free until you get a job. I have made remarks that I do not agree with.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 101982,
#     'friends_count': 10670,
#     'listed_count': 2096,
#     'created_at': 'Wed Dec 01 19:13:23 +0000 2010',
#     'favourites_count': 50279,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 15501,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/505117931332583425/y7xFUr-l_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/505117931332583425/y7xFUr-l_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/221838349/1408222178',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': True,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'created_at': 'Wed May 15 00:38:06 +0000 2019',
#    'id': 1128459504105009154,
#    'id_str': '1128459504105009154',
#    'full_text': '@crawfteevee @DstarDev Well, Crawford closed it down with the Monty Python reference. Sorry.',
#    'truncated': False,
#    'display_text_range': [23, 92],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'crawfteevee',
#       'name': 'crawford',
#       'id': 954460588977086465,
#       'id_str': '954460588977086465',
#       'indices': [0, 12]},
#      {'screen_name': 'DstarDev',
#       'name': 'DstarDev',
#       'id': 1123316691100786688,
#       'id_str': '1123316691100786688',
#       'indices': [13, 22]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': 1128448302880632832,
#    'in_reply_to_status_id_str': '1128448302880632832',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 32161686,
#     'id_str': '32161686',
#     'name': 'Nick Durbin',
#     'screen_name': 'durbdawg',
#     'location': 'OH',
#     'description': 'WEBpt8 @Lambdaschool | Cleveland Sports Fan | I love life & people. We all have the capacity to make a change for the betterment of our world.',
#     'url': 'https://t.co/snpE3B0UDM',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/snpE3B0UDM',
#         'expanded_url': 'http://youtube.com/HobbifiedLife',
#         'display_url': 'youtube.com/HobbifiedLife',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 814,
#     'friends_count': 381,
#     'listed_count': 15,
#     'created_at': 'Thu Apr 16 21:32:17 +0000 2009',
#     'favourites_count': 6527,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4070,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1026469582322561025/nINtWJxY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1026469582322561025/nINtWJxY_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/32161686/1547848138',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0,
#    'toxic': 0.0002}},
#  {'tweet': {'created_at': 'Thu Apr 25 01:51:30 +0000 2019',
#    'id': 1121230220357275648,
#    'id_str': '1121230220357275648',
#    'full_text': '@wawacat2 @bwinterrose @crawfteevee Very fascinating and beautiful process. Feels rewarding in a unique way to see these grow.',
#    'truncated': False,
#    'display_text_range': [36, 126],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'wawacat2',
#       'name': 'wawa cat',
#       'id': 1068900689076805632,
#       'id_str': '1068900689076805632',
#       'indices': [0, 9]},
#      {'screen_name': 'bwinterrose',
#       'name': 'Britton',
#       'id': 920935903,
#       'id_str': '920935903',
#       'indices': [10, 22]},
#      {'screen_name': 'crawfteevee',
#       'name': 'crawford',
#       'id': 954460588977086465,
#       'id_str': '954460588977086465',
#       'indices': [23, 35]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1121229472018178048,
#    'in_reply_to_status_id_str': '1121229472018178048',
#    'in_reply_to_user_id': 1068900689076805632,
#    'in_reply_to_user_id_str': '1068900689076805632',
#    'in_reply_to_screen_name': 'wawacat2',
#    'user': {'id': 2786431437,
#     'id_str': '2786431437',
#     'name': 'Mckay Wrigley',
#     'screen_name': 'mckaywrigley',
#     'location': 'A Spaceship Called Earth',
#     'description': 'Do not go gentle into that good night. @lambdaschool Web18',
#     'url': 'https://t.co/CANMVSoOEN',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/CANMVSoOEN',
#         'expanded_url': 'http://mckaywrigley.com',
#         'display_url': 'mckaywrigley.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1700,
#     'friends_count': 197,
#     'listed_count': 27,
#     'created_at': 'Fri Sep 26 23:44:05 +0000 2014',
#     'favourites_count': 32295,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1687,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/958648673071706113/yx-jX3o1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/958648673071706113/yx-jX3o1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2786431437/1548441517',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'created_at': 'Thu Apr 25 01:27:23 +0000 2019',
#    'id': 1121224150666735616,
#    'id_str': '1121224150666735616',
#    'full_text': '@bwinterrose @crawfteevee Super excited! First time grower so feeling pretty lucky I didn’t ruin it. So far.',
#    'truncated': False,
#    'display_text_range': [26, 108],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'bwinterrose',
#       'name': 'Britton',
#       'id': 920935903,
#       'id_str': '920935903',
#       'indices': [0, 12]},
#      {'screen_name': 'crawfteevee',
#       'name': 'crawford',
#       'id': 954460588977086465,
#       'id_str': '954460588977086465',
#       'indices': [13, 25]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1121223239240306688,
#    'in_reply_to_status_id_str': '1121223239240306688',
#    'in_reply_to_user_id': 920935903,
#    'in_reply_to_user_id_str': '920935903',
#    'in_reply_to_screen_name': 'bwinterrose',
#    'user': {'id': 2786431437,
#     'id_str': '2786431437',
#     'name': 'Mckay Wrigley',
#     'screen_name': 'mckaywrigley',
#     'location': 'A Spaceship Called Earth',
#     'description': 'Do not go gentle into that good night. @lambdaschool Web18',
#     'url': 'https://t.co/CANMVSoOEN',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/CANMVSoOEN',
#         'expanded_url': 'http://mckaywrigley.com',
#         'display_url': 'mckaywrigley.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1700,
#     'friends_count': 197,
#     'listed_count': 27,
#     'created_at': 'Fri Sep 26 23:44:05 +0000 2014',
#     'favourites_count': 32295,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1687,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/958648673071706113/yx-jX3o1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/958648673071706113/yx-jX3o1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2786431437/1548441517',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'created_at': 'Thu Apr 25 01:23:46 +0000 2019',
#    'id': 1121223239240306688,
#    'id_str': '1121223239240306688',
#    'full_text': '@mckaywrigley Nice! Watermelon is the best. \n@crawfteevee loves watermelon.',
#    'truncated': False,
#    'display_text_range': [14, 75],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mckaywrigley',
#       'name': 'Mckay Wrigley',
#       'id': 2786431437,
#       'id_str': '2786431437',
#       'indices': [0, 13]},
#      {'screen_name': 'crawfteevee',
#       'name': 'crawford',
#       'id': 954460588977086465,
#       'id_str': '954460588977086465',
#       'indices': [45, 57]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': 1121219311253606400,
#    'in_reply_to_status_id_str': '1121219311253606400',
#    'in_reply_to_user_id': 2786431437,
#    'in_reply_to_user_id_str': '2786431437',
#    'in_reply_to_screen_name': 'mckaywrigley',
#    'user': {'id': 920935903,
#     'id_str': '920935903',
#     'name': 'Britton',
#     'screen_name': 'bwinterrose',
#     'location': 'Salt Lake City, UT',
#     'description': 'Data Scientist - AI/ML, @LambdaSchool student, 2x Founder.',
#     'url': 'https://t.co/PVlu9GapyL',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PVlu9GapyL',
#         'expanded_url': 'https://www.linkedin.com/in/brittonwinterrose/',
#         'display_url': 'linkedin.com/in/brittonwint…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 700,
#     'friends_count': 753,
#     'listed_count': 19,
#     'created_at': 'Fri Nov 02 12:30:44 +0000 2012',
#     'favourites_count': 12519,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2195,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1032911814902915072/9l97toJR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1032911814902915072/9l97toJR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/920935903/1495517627',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': True,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'created_at': 'Fri Mar 29 11:11:28 +0000 2019',
#    'id': 1111586667477913600,
#    'id_str': '1111586667477913600',
#    'full_text': '@crawfteevee @Austen 3x. After needed to change office i realized that in office hours, while i am in there, my huge apartmant is just wasteful empty. So i got a few desks for living room and bring my team of 6 to work at my home once a week. Other days all can stay home. Super happy with results.',
#    'truncated': False,
#    'display_text_range': [21, 298],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'crawfteevee',
#       'name': 'crawford',
#       'id': 954460588977086465,
#       'id_str': '954460588977086465',
#       'indices': [0, 12]},
#      {'screen_name': 'Austen',
#       'name': 'Austen Allred',
#       'id': 221838349,
#       'id_str': '221838349',
#       'indices': [13, 20]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1111510451819593728,
#    'in_reply_to_status_id_str': '1111510451819593728',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 2302718912,
#     'id_str': '2302718912',
#     'name': 'BiggerBetterGreener',
#     'screen_name': 'biggergreener',
#     'location': 'World-Wide (USA/CA/EUR/ASIA)',
#     'description': 'Marketer, Huster, Entrepreneur, Startup Supporter, eCommerce fanatic, ex Art Director at $60M Media Company, Traveler, Dad. Selling https://t.co/gC0RaG1f0n right now!',
#     'url': 'https://t.co/0qyvGtH7OM',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0qyvGtH7OM',
#         'expanded_url': 'https://mission.ai',
#         'display_url': 'mission.ai',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/gC0RaG1f0n',
#         'expanded_url': 'http://Mission.ai',
#         'display_url': 'Mission.ai',
#         'indices': [132, 155]}]}},
#     'protected': False,
#     'followers_count': 135,
#     'friends_count': 530,
#     'listed_count': 32,
#     'created_at': 'Tue Jan 21 08:15:52 +0000 2014',
#     'favourites_count': 1176,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 828,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1062162483245277185/CDo_TUuy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1062162483245277185/CDo_TUuy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2302718912/1436499093',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0002,
#    'obscene': 0.0002,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0008}},
#  {'tweet': {'created_at': 'Tue Jan 01 08:36:40 +0000 2019',
#    'id': 1080019968555708416,
#    'id_str': '1080019968555708416',
#    'full_text': '@crawfteevee @AustenAllred Complete agreement of all replies that granola is candy :-)',
#    'truncated': False,
#    'display_text_range': [27, 86],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'crawfteevee',
#       'name': 'crawford',
#       'id': 954460588977086465,
#       'id_str': '954460588977086465',
#       'indices': [0, 12]},
#      {'screen_name': 'AustenAllred',
#       'name': 'Austen Allred',
#       'id': 1093528151123095552,
#       'id_str': '1093528151123095552',
#       'indices': [13, 26]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1079746961522257921,
#    'in_reply_to_status_id_str': '1079746961522257921',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 843308749012066304,
#     'id_str': '843308749012066304',
#     'name': 'Peter Tobias',
#     'screen_name': 'PeterTobias8',
#     'location': 'Minnesota, USA',
#     'description': 'Physicist.\nInterested in science and politics.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 146,
#     'friends_count': 160,
#     'listed_count': 1,
#     'created_at': 'Sun Mar 19 03:50:48 +0000 2017',
#     'favourites_count': 21341,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7490,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1050993600480325632/Nhd_BrdG_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1050993600480325632/Nhd_BrdG_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/843308749012066304/1540964017',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0005}},
#  {'tweet': {'created_at': 'Fri Oct 05 22:22:55 +0000 2018',
#    'id': 1048337767393107970,
#    'id_str': '1048337767393107970',
#    'full_text': '@crawfu1 @PaulSkallas for example?',
#    'truncated': False,
#    'display_text_range': [22, 34],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PaulSkallas',
#       'name': 'Paul (99%)',
#       'id': 886358633646350340,
#       'id_str': '886358633646350340',
#       'indices': [9, 21]}],
#     'urls': []},
#    'source': '<a href="https://play.google.com/store/apps/details?id=com.arthurivanets.owly" rel="nofollow">Оwly</a>',
#    'in_reply_to_status_id': 1048334640443019267,
#    'in_reply_to_status_id_str': '1048334640443019267',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 59281385,
#     'id_str': '59281385',
#     'name': 'Matthieu',
#     'screen_name': 'xyzmatthieu',
#     'location': 'Social Proof for Twitter',
#     'description': 'precog, conscious AI, time sensitive',
#     'url': 'https://t.co/W2rriXsSYs',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/W2rriXsSYs',
#         'expanded_url': 'https://chrome.google.com/webstore/detail/social-proof-for-twitter/jefcjopolhodlepaicbhombbblofoole',
#         'display_url': 'chrome.google.com/webstore/detai…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 407,
#     'friends_count': 176,
#     'listed_count': 6,
#     'created_at': 'Wed Jul 22 23:02:22 +0000 2009',
#     'favourites_count': 39553,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2284,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/830485374094962688/iyIvF5TI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830485374094962688/iyIvF5TI_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/59281385/1486838851',
#     'profile_link_color': 'F58EA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'created_at': 'Thu Aug 16 20:49:26 +0000 2018',
#    'id': 1030194847402082305,
#    'id_str': '1030194847402082305',
#    'full_text': "@crawfu1 The definition of introvert isn't real considering it has all these qualifiers. So going on stage doesn't matter but wearing sunglasses makes it ok. I don't know.",
#    'truncated': False,
#    'display_text_range': [9, 171],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1030194235960700928,
#    'in_reply_to_status_id_str': '1030194235960700928',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 886358633646350340,
#     'id_str': '886358633646350340',
#     'name': 'Paul (99%)',
#     'screen_name': 'PaulSkallas',
#     'location': 'NY',
#     'description': '@LindyEffect',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2981,
#     'friends_count': 443,
#     'listed_count': 39,
#     'created_at': 'Sat Jul 15 22:55:40 +0000 2017',
#     'favourites_count': 14906,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 19085,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1039644617136857088/LvAkHwWr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1039644617136857088/LvAkHwWr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/886358633646350340/1536721848',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0002,
#    'obscene': 0.0002,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0007}},
#  {'tweet': {'created_at': 'Thu Aug 16 08:27:38 +0000 2018',
#    'id': 1030008165964890112,
#    'id_str': '1030008165964890112',
#    'full_text': '@brettfarrow @crawfu1 @webdevMason @dansmith_tweets I volunteered at a private school once. Most teachers there had switched over from public schools &amp; taken a pay cut for exactly those reasons. Headmaster said they were getting requests from public-school teachers all the time.',
#    'truncated': False,
#    'display_text_range': [52, 283],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'brettfarrow',
#       'name': 'Brett Farrow',
#       'id': 14377610,
#       'id_str': '14377610',
#       'indices': [0, 12]},
#      {'screen_name': 'webdevMason',
#       'name': 'Mason 🏃🏻✂️',
#       'id': 3289153303,
#       'id_str': '3289153303',
#       'indices': [22, 34]},
#      {'screen_name': 'dansmith_tweets',
#       'name': 'Dan Smith',
#       'id': 1413642236,
#       'id_str': '1413642236',
#       'indices': [35, 51]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1029781487380512769,
#    'in_reply_to_status_id_str': '1029781487380512769',
#    'in_reply_to_user_id': 14377610,
#    'in_reply_to_user_id_str': '14377610',
#    'in_reply_to_screen_name': 'brettfarrow',
#    'user': {'id': 886987824989384704,
#     'id_str': '886987824989384704',
#     'name': 'Francesca Pallopides',
#     'screen_name': 'FPallopides',
#     'location': 'Europe',
#     'description': 'asymmetrical girl · pretty sure we need to rethink everything including feminism',
#     'url': 'https://t.co/5c6VzclciC',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/5c6VzclciC',
#         'expanded_url': 'https://contemporarysex.tumblr.com/',
#         'display_url': 'contemporarysex.tumblr.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 194,
#     'friends_count': 1180,
#     'listed_count': 2,
#     'created_at': 'Mon Jul 17 16:35:51 +0000 2017',
#     'favourites_count': 6087,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4597,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/886996131418439680/aWhU_Ol8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/886996131418439680/aWhU_Ol8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/886987824989384704/1500311473',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'created_at': 'Wed Aug 15 17:26:53 +0000 2018',
#    'id': 1029781487380512769,
#    'id_str': '1029781487380512769',
#    'full_text': '@crawfu1 @webdevMason @dansmith_tweets I don’t know if that’s the case, or if it’s because private school numbers are deflated by religious schools that pay less.',
#    'truncated': False,
#    'display_text_range': [39, 162],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'webdevMason',
#       'name': 'Mason 🏃🏻✂️',
#       'id': 3289153303,
#       'id_str': '3289153303',
#       'indices': [9, 21]},
#      {'screen_name': 'dansmith_tweets',
#       'name': 'Dan Smith',
#       'id': 1413642236,
#       'id_str': '1413642236',
#       'indices': [22, 38]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1029769354429300736,
#    'in_reply_to_status_id_str': '1029769354429300736',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 14377610,
#     'id_str': '14377610',
#     'name': 'Brett Farrow',
#     'screen_name': 'brettfarrow',
#     'location': 'Colorado Springs, CO',
#     'description': 'I mostly retweet dogs and other funny things | Co-Founder @SpaceTogetherCO',
#     'url': 'https://t.co/k78YKEkmWg',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/k78YKEkmWg',
#         'expanded_url': 'https://spacetogether.com',
#         'display_url': 'spacetogether.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 281,
#     'friends_count': 106,
#     'listed_count': 6,
#     'created_at': 'Sun Apr 13 20:24:05 +0000 2008',
#     'favourites_count': 5301,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3124,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/461342040177917952/KzVebECu_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/461342040177917952/KzVebECu_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14377610/1398827456',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0002,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0003}},
#  {'tweet': {'created_at': 'Mon Jul 16 03:52:26 +0000 2018',
#    'id': 1018704885611618304,
#    'id_str': '1018704885611618304',
#    'full_text': '@crawfu1 The reasonable position (i.e. we should establish some threshold of meat-product parity that we enforce socially) is perfectly consistent with use of medical technologies once safety is established.\n\nBut they stem from essentially similar science, hence the hypocrisy.',
#    'truncated': False,
#    'display_text_range': [9, 277],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1018693935462567936,
#    'in_reply_to_status_id_str': '1018693935462567936',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 15614600,
#     'id_str': '15614600',
#     'name': 'Matthew Pirkowski',
#     'screen_name': 'MattPirkowski',
#     'location': 'San Francisco, CA',
#     'description': 'Bringing Order to Chaos, and Chaos to Order.',
#     'url': 'https://t.co/ydBNbIieFw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ydBNbIieFw',
#         'expanded_url': 'http://matthewpirkowski.com',
#         'display_url': 'matthewpirkowski.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2125,
#     'friends_count': 776,
#     'listed_count': 64,
#     'created_at': 'Sat Jul 26 21:41:45 +0000 2008',
#     'favourites_count': 3106,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7674,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15614600/1492464004',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'created_at': 'Mon Jul 16 03:07:29 +0000 2018',
#    'id': 1018693575293333506,
#    'id_str': '1018693575293333506',
#    'full_text': '@crawfu1 Yes, and this can likely be emulated with increasing fidelity over time. \n\nWe’re not talking about magical pixie dust, here. It’s a matter of matching physical properties.\n\nAdditionally it will be free of unnecessary hormones, antibiotics etc.',
#    'truncated': False,
#    'display_text_range': [9, 252],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1018692184999153664,
#    'in_reply_to_status_id_str': '1018692184999153664',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 15614600,
#     'id_str': '15614600',
#     'name': 'Matthew Pirkowski',
#     'screen_name': 'MattPirkowski',
#     'location': 'San Francisco, CA',
#     'description': 'Bringing Order to Chaos, and Chaos to Order.',
#     'url': 'https://t.co/ydBNbIieFw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ydBNbIieFw',
#         'expanded_url': 'http://matthewpirkowski.com',
#         'display_url': 'matthewpirkowski.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2125,
#     'friends_count': 776,
#     'listed_count': 64,
#     'created_at': 'Sat Jul 26 21:41:45 +0000 2008',
#     'favourites_count': 3106,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7674,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15614600/1492464004',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'created_at': 'Sun Jul 15 17:08:47 +0000 2018',
#    'id': 1018542908096614400,
#    'id_str': '1018542908096614400',
#    'full_text': '@crawfu1 @MattPirkowski Actually it might given the fact that most pigs &amp; chickens raised for meat in industrial factory farms have higher levels of stress hormones, are fed antibiotics, growth hormones and other shit that lead to cancer and infectious outbreaks; also there’s the environmental impact.',
#    'truncated': False,
#    'display_text_range': [24, 306],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MattPirkowski',
#       'name': 'Matthew Pirkowski',
#       'id': 15614600,
#       'id_str': '15614600',
#       'indices': [9, 23]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1017902535741509633,
#    'in_reply_to_status_id_str': '1017902535741509633',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 954465600159576065,
#     'id_str': '954465600159576065',
#     'name': 'Crypto Alien Limb Phenomenon',
#     'screen_name': 'cryptogeni',
#     'location': 'Pale Blue Dot',
#     'description': '+HINTS -Any of these: 1) Bidirectional nystagmus 2) Abnormal test of skew 3) Normal head impulse test (Parody, Shit-posting Account; You have been warned!)',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 274,
#     'friends_count': 1160,
#     'listed_count': 2,
#     'created_at': 'Fri Jan 19 21:28:27 +0000 2018',
#     'favourites_count': 14432,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1426,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1097783570989486081/M96jCYiv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097783570989486081/M96jCYiv_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/954465600159576065/1516405126',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0002,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0,
#    'toxic': 0.0006}},
#  {'tweet': {'created_at': 'Sat Jul 14 02:54:31 +0000 2018',
#    'id': 1017965538276884480,
#    'id_str': '1017965538276884480',
#    'full_text': "@crawfu1 If you'd like to answer my questions, I'll take the time to answer yours.",
#    'truncated': False,
#    'display_text_range': [9, 82],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': 1017902535741509633,
#    'in_reply_to_status_id_str': '1017902535741509633',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 15614600,
#     'id_str': '15614600',
#     'name': 'Matthew Pirkowski',
#     'screen_name': 'MattPirkowski',
#     'location': 'San Francisco, CA',
#     'description': 'Bringing Order to Chaos, and Chaos to Order.',
#     'url': 'https://t.co/ydBNbIieFw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ydBNbIieFw',
#         'expanded_url': 'http://matthewpirkowski.com',
#         'display_url': 'matthewpirkowski.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2125,
#     'friends_count': 776,
#     'listed_count': 64,
#     'created_at': 'Sat Jul 26 21:41:45 +0000 2008',
#     'favourites_count': 3106,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7674,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15614600/1492464004',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'created_at': 'Fri Jul 13 21:05:56 +0000 2018',
#    'id': 1017877813599145984,
#    'id_str': '1017877813599145984',
#    'full_text': '@crawfu1 If indistinguishable, what is artificial about them? \n\nFor example, regarding function, what differentiates a diamond made by humans in a day from those made by nature over millennia?\n\nThe differentiation in language flows mainly from those who seek to maintain the status quo.',
#    'truncated': False,
#    'display_text_range': [9, 286],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': 1017862960809639936,
#    'in_reply_to_status_id_str': '1017862960809639936',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 15614600,
#     'id_str': '15614600',
#     'name': 'Matthew Pirkowski',
#     'screen_name': 'MattPirkowski',
#     'location': 'San Francisco, CA',
#     'description': 'Bringing Order to Chaos, and Chaos to Order.',
#     'url': 'https://t.co/ydBNbIieFw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ydBNbIieFw',
#         'expanded_url': 'http://matthewpirkowski.com',
#         'display_url': 'matthewpirkowski.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2125,
#     'friends_count': 776,
#     'listed_count': 64,
#     'created_at': 'Sat Jul 26 21:41:45 +0000 2008',
#     'favourites_count': 3106,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7674,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15614600/1492464004',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'created_at': 'Fri Jul 13 19:06:41 +0000 2018',
#    'id': 1017847801219125249,
#    'id_str': '1017847801219125249',
#    'full_text': '@crawfu1 Elaborate on why you think so.',
#    'truncated': False,
#    'display_text_range': [9, 39],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': 1017845879447924738,
#    'in_reply_to_status_id_str': '1017845879447924738',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 15614600,
#     'id_str': '15614600',
#     'name': 'Matthew Pirkowski',
#     'screen_name': 'MattPirkowski',
#     'location': 'San Francisco, CA',
#     'description': 'Bringing Order to Chaos, and Chaos to Order.',
#     'url': 'https://t.co/ydBNbIieFw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ydBNbIieFw',
#         'expanded_url': 'http://matthewpirkowski.com',
#         'display_url': 'matthewpirkowski.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2125,
#     'friends_count': 776,
#     'listed_count': 64,
#     'created_at': 'Sat Jul 26 21:41:45 +0000 2008',
#     'favourites_count': 3106,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7674,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1094715836537831424/PUF71ujV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15614600/1492464004',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'created_at': 'Wed Jul 04 17:48:32 +0000 2018',
#    'id': 1014566644528472064,
#    'id_str': '1014566644528472064',
#    'full_text': '@crawfu1 By the time the steer/heifer is slaughtered, it underwent a drug whithdrawal time. At the time we eat the beef products, there is basically next to nothing left.',
#    'truncated': False,
#    'display_text_range': [9, 170],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1014547989984153602,
#    'in_reply_to_status_id_str': '1014547989984153602',
#    'in_reply_to_user_id': 954460588977086465,
#    'in_reply_to_user_id_str': '954460588977086465',
#    'in_reply_to_screen_name': 'crawfteevee',
#    'user': {'id': 95715569,
#     'id_str': '95715569',
#     'name': 'Frank Mitloehner',
#     'screen_name': 'GHGGuru',
#     'location': 'Davis, CA',
#     'description': 'UC Davis Professor & Air quality specialist, Animal Science; Opinions are mine',
#     'url': 'https://t.co/HxJhSV817h',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/HxJhSV817h',
#         'expanded_url': 'https://www.researchgate.net/profile/Frank_Mitloehner?ev=hdr_xprf&_sg=TtHgE5RkHZWo_7ukekCjfvzSXL4uf5',
#         'display_url': 'researchgate.net/profile/Frank_…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8630,
#     'friends_count': 1778,
#     'listed_count': 99,
#     'created_at': 'Wed Dec 09 19:37:25 +0000 2009',
#     'favourites_count': 7736,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4939,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/984936528693477376/FSAskRDM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/984936528693477376/FSAskRDM_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/95715569/1523919387',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '1994142e26ba7127',
#     'url': 'https://api.twitter.com/1.1/geo/id/1994142e26ba7127.json',
#     'place_type': 'city',
#     'name': 'Davis',
#     'full_name': 'Davis, CA',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-121.803252, 38.526843],
#        [-121.675074, 38.526843],
#        [-121.675074, 38.590264],
#        [-121.803252, 38.590264]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0003}}]
