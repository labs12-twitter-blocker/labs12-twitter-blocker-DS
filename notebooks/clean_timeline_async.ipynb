# %%
# %load_ext blackcellmagic

# %%
import tweepy
import re
from decouple import config
import json
import requests
import sys

TWITTER_AUTH = tweepy.OAuthHandler(config('TWITTER_CONSUMER_KEY'),config('TWITTER_CONSUMER_SECRET'))

TWITTER_AUTH.set_access_token(config('TWITTER_ACCESS_TOKEN'),config('TWITTER_ACCESS_TOKEN_SECRET'))

TWITTER = tweepy.API(TWITTER_AUTH)

# %%
TWITTER_ACCESS_TOKEN =config('TWITTER_ACCESS_TOKEN')
TWITTER_ACCESS_TOKEN_SECRET =config('TWITTER_ACCESS_TOKEN_SECRET')

# %%
import tweepy
import re
from decouple import config
import json
import requests
import sys
import asyncio
from concurrent.futures import ThreadPoolExecutor
import nest_asyncio
from itertools import zip_longest

nest_asyncio.apply()


def process_request(request):
    """ Responds to a GET request with "Hello world!". Forbids a PUT request.
    Args:
        request (flask.Request): The request object.
        <http://flask.pocoo.org/docs/1.0/api/#flask.Request>
    Returns:
        The response text, or any set of values that can be turned into a
         Response object using `make_response`
        <http://flask.pocoo.org/docs/1.0/api/#flask.Flask.make_response>.
    """
    from flask import abort

    content_type = request.headers["content-type"]
    request_json = request.get_json(silent=True)
    request_args = request.args

    if content_type == "application/json":
        request_json = request.get_json(silent=True)
        # TWITTER_ACCESS_TOKEN check/set/error
        if request_json and "TWITTER_ACCESS_TOKEN" in request_json:
            TWITTER_ACCESS_TOKEN = request_json["TWITTER_ACCESS_TOKEN"]
        else:
            raise ValueError("Missing a 'TWITTER_ACCESS_TOKEN'")
        # TWITTER_ACCESS_TOKEN_SECRET check/set/error
        if request_json and "TWITTER_ACCESS_TOKEN_SECRET" in request_json:
            TWITTER_ACCESS_TOKEN_SECRET = request_json["TWITTER_ACCESS_TOKEN_SECRET"]
        else:
            raise ValueError("Missing a 'TWITTER_ACCESS_TOKEN_SECRET'")

        if request_json and "num_pages" in request_json:
            num_pages = request_json["num_pages"]
        else:
            num_pages = 1

        # Call the function for the POST request.
        if request.method == "POST":
            return execute_async_index_event_loop(
                TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET, num_pages
            )
    else:
        return abort(405)


def execute_async_index_event_loop(
    TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET, num_pages
):
    """Really couldn't think of a proper name. 
    This function does something analogous to compiling the get_data_asynchronously funciont,
    Then it executes loop."""
    final_output = []
    mentions_timeline = get_mentions(
        TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET, final_output, num_pages
    )
    future = asyncio.ensure_future(
        get_index_data_asynchronous(
            TWITTER_ACCESS_TOKEN,
            TWITTER_ACCESS_TOKEN_SECRET,
            final_output,
            num_pages,
            mentions_timeline,
        )
    )
    loop = asyncio.get_event_loop()
    loop.run_until_complete(future)
    final_output = {"results": final_output}
    return json.dumps(final_output)

def get_mentions(
    TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET, final_output, num_pages
):
    # Create Twitter Connection
    twitter_auth = tweepy.OAuthHandler(
        config("TWITTER_CONSUMER_KEY"), config("TWITTER_CONSUMER_SECRET")
    )
    access_token = TWITTER_ACCESS_TOKEN
    access_token_secret = TWITTER_ACCESS_TOKEN_SECRET
    twitter_auth.set_access_token(access_token, access_token_secret)
    global TWITTER
    TWITTER = tweepy.API(twitter_auth)
    try:
        home_timeline = TWITTER.mentions_timeline(
            count=32 * num_pages, tweet_mode="extended", exclude_rts=False
        )
        timeline = [process_tweet(full_tweet) for full_tweet in home_timeline]
        # create list of lists where sublists = 32 for BERT model
        z = grouper(timeline, 32)
        timeline = [[i for i in subz if i is not None] for subz in z]
        return timeline

    except tweepy.TweepError:
        print("tweepy.TweepError")

    except:
        e = sys.exc_info()[0]
        print("mentions_timeline: Error: %s" % e)


async def get_index_data_asynchronous(
    TWITTER_ACCESS_TOKEN,
    TWITTER_ACCESS_TOKEN_SECRET,
    final_output,
    num_pages,
    mentions_timeline,
):
    with ThreadPoolExecutor(max_workers=20) as executor:
        with requests.Session() as session:
            loop = asyncio.get_event_loop()
            tasks = [
                loop.run_in_executor(
                    executor,
                    clean_timeline,
                    *(
                        session,
                        TWITTER_ACCESS_TOKEN,
                        TWITTER_ACCESS_TOKEN_SECRET,
                        final_output,
                        page,
                    )
                )
                for page in range(num_pages)
            ] + [
                loop.run_in_executor(
                    executor, clean_mentions, *(session, sub_timeline, final_output)
                )
                for sub_timeline in mentions_timeline
            ]
            for response in await asyncio.gather(*tasks):
                pass

def clean_timeline(
    session, TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET, final_output, page
):
    # Create Twitter Connection
    twitter_auth = tweepy.OAuthHandler(
        config("TWITTER_CONSUMER_KEY"), config("TWITTER_CONSUMER_SECRET")
    )
    access_token = TWITTER_ACCESS_TOKEN
    access_token_secret = TWITTER_ACCESS_TOKEN_SECRET
    twitter_auth.set_access_token(access_token, access_token_secret)
    global TWITTER
    TWITTER = tweepy.API(twitter_auth)
    
    try:
        home_timeline = TWITTER.home_timeline(
            count=32,
            tweet_mode="extended",
            exlude_rts=False,
            exclude_replies=False,
            page=page,
        )
        home_timeline = [process_tweet(full_tweet) for full_tweet in home_timeline]
        output = bert_request(home_timeline)
        final_output += output

    except tweepy.TweepError:
        print("clean_timeline: tweepy.TweepError")

    except:
        e = sys.exc_info()[0]
        print("clean_timeline: Error: %s" % e)


def clean_mentions(session, sub_timeline, final_output):
    final_output += bert_request(sub_timeline)


def process_tweet(full_tweet):
    tweet = full_tweet.full_text
    # strip username
    tweet = re.sub(r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))@([A-Za-z]+[A-Za-z0-9-_]+)", "", tweet)
    # strip newlines and unicode characters that aren't formatted
    tweet = re.sub(r"\n|&gt;|RT :", "", tweet)
    # strip twitter urls from tweets
    tweet = re.sub(
        r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))https://t.co/([A-Za-z0-9-_,\']+)", "", tweet
    )
    # Remove emojis
    RE_EMOJI = re.compile("[\U00010000-\U0010ffff]", flags=re.UNICODE)
    tweet = RE_EMOJI.sub(r"", tweet)
    # remove whitespace
    tweet = tweet.strip()
    # make api request for toxicity analysis

    tweet_info = {
        "tweet": {
            "user_id": full_tweet.user.id,
            "user_name": full_tweet.user.name,
            "tweet": full_tweet.full_text,
            "tweet_id": full_tweet.id_str,
        }
    }
    return tweet_info


def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    # grouper('ABCDEFG', 3, 'x') --> ABC DEF Gxx
    args = [iter(iterable)] * n
    return zip_longest(fillvalue=fillvalue, *args)


def bert_request(sub_timeline):
    tweet_list = [tweet["tweet"]["tweet"] for tweet in sub_timeline]
    data = {"description": tweet_list, "max_seq_length": 32}
    headers = {"Content-type": "application/json", "cache-control": "no-cache"}
    data = json.dumps(data)
    results = requests.post("http://35.222.5.199:5000/", data=data, headers=headers).json()["results"]
    # results is a list comprehension of zipping tweet & bert_result lists
    # and making two dictionary key,values out of each.
    output = [
        {"tweet": t["tweet"], "bert_result": r}
        for t, r in zip(sub_timeline, results)
    ]
    return output

# %%
# %%time
z = execute_async_index_event_loop(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET, 2)
# Out:
# clean_timeline: Error: <class 'json.decoder.JSONDecodeError'>
# clean_timeline: Error: <class 'json.decoder.JSONDecodeError'>
# Wall time: 11.9 s

# %%
def bert_request(sub_timeline):
    tweet_list = [tweet["tweet"]["tweet"] for tweet in sub_timeline]
    data = {"description": tweet_list, "max_seq_length": 32}
    headers = {"Content-type": "application/json", "cache-control": "no-cache"}
    data = json.dumps(data)
    results = requests.post("http://35.222.5.199:5000/", data=data, headers=headers).json()["results"]
    output = [
        {"tweet": t["tweet"], "bert_result": r}
        for t, r in zip(sub_timeline, results)
    ]
    return output

def clean_timeline(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET, page
):
    # Create Twitter Connection
    twitter_auth = tweepy.OAuthHandler(
        config("TWITTER_CONSUMER_KEY"), config("TWITTER_CONSUMER_SECRET")
    )
    access_token = TWITTER_ACCESS_TOKEN
    access_token_secret = TWITTER_ACCESS_TOKEN_SECRET
    twitter_auth.set_access_token(access_token, access_token_secret)
    global TWITTER
    TWITTER = tweepy.API(twitter_auth)
    
    home_timeline = TWITTER.home_timeline(
            count=32,
            tweet_mode="extended",
            exlude_rts=False,
            exclude_replies=False,
            page=page,
        )
    home_timeline = [process_tweet(full_tweet) for full_tweet in home_timeline]
    return home_timeline

# %%
z= bert_request(clean_timeline(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET, 1))

# %%
z
# Out:
# [{'tweet': {'user_id': 321014839,
#    'user_name': 'Starting Strength',
#    'tweet': '"Saying that you don\'t want to lift weights because you\'ll get too big is like saying that you don’t want to get your driver’s license because  you\'re afraid you\'ll become a NASCAR driver." https://t.co/15BUOQ9beV',
#    'tweet_id': '1128702862039691266'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0006,
#    'obscene': 0.0004,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0028}},
#  {'tweet': {'user_id': 3765572533,
#    'user_name': 'Dr Shawn Baker 🥩',
#    'tweet': 'RT @mrsmarvey: @rolyatinator @SBakerMD @fjrtraveler @eallen83 Another  "lefty lib" here who eats meat almost exclusively. FYI, I personally…',
#    'tweet_id': '1128702754501697536'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0001,
#    'obscene': 0.0002,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0004}},
#  {'tweet': {'user_id': 3765572533,
#    'user_name': 'Dr Shawn Baker 🥩',
#    'tweet': 'https://t.co/ji0VbdHDBJ',
#    'tweet_id': '1128702168003801088'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0004}},
#  {'tweet': {'user_id': 20178419,
#    'user_name': 'Charlie Warzel',
#    'tweet': 'this is a nonbinding pledge w/o enforcement or regulatory measures. it is an acknowledgment that countries and platforms need to work together to curb violent/extremist content. the stakes of signing are low, which means not signing signals the true values of this administration. https://t.co/h89K7t7luz',
#    'tweet_id': '1128701486144282624'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'user_id': 1536600704,
#    'user_name': 'Alex Griswold',
#    'tweet': 'The Michigan Glee Club sang in my house and then I kicked them out, does that count',
#    'tweet_id': '1128700667609137152'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0002,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0005}},
#  {'tweet': {'user_id': 23909137,
#    'user_name': 'Larry Brown',
#    'tweet': 'RT @SteveDelSports: Sean Payton wastes no time recruiting Zion Williamson to Saints https://t.co/XSnzZ0SYpi',
#    'tweet_id': '1128700101956964352'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'user_id': 4916001683,
#    'user_name': 'Pardon My Take',
#    'tweet': 'RT @BarstoolBigCat: I got unfollowed by @AnnaKendrick47, this is devastating. Should have kept my fat mouth shut',
#    'tweet_id': '1128699843579469825'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'user_id': 252608121,
#    'user_name': 'Yaneer Bar-Yam',
#    'tweet': 'Combinatorial challenge https://t.co/nQ88oQ5FRn',
#    'tweet_id': '1128697892968050690'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'user_id': 87829185,
#    'user_name': 'B. Miller',
#    'tweet': 'The Jets will always be the Jets.',
#    'tweet_id': '1128697490377719808'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'user_id': 4916001683,
#    'user_name': 'Pardon My Take',
#    'tweet': 'RT @BarstoolBigCat: Brooks Koepka is my new favorite recurring @PardonMyTake guest. https://t.co/7dwJtslJXT',
#    'tweet_id': '1128697479271202817'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'user_id': 1536600704,
#    'user_name': 'Alex Griswold',
#    'tweet': '-America\n\n-Chicago played before the Cotton Bowl\n\n-Nick Lachey played at my middle school because we raised money or something\n\nI think that’s it',
#    'tweet_id': '1128697089540669440'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'user_id': 1536600704,
#    'user_name': 'Alex Griswold',
#    'tweet': 'I can’t do the fun “name five bands you’ve seen and one fake one” thing because I literally don’t think i’ve been to five concerts in my entire life',
#    'tweet_id': '1128696507128057856'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0005,
#    'obscene': 0.0006,
#    'severe_toxic': 0.0002,
#    'threat': 0.0001,
#    'toxic': 0.0011}},
#  {'tweet': {'user_id': 858716964,
#    'user_name': 'PFTCommenter',
#    'tweet': 'Very rare to have a initial interview w a new guest and get to the core of who they are as a person. Brooks on shortlist for 2019 Brooks of the Year Takey award https://t.co/Exrn0TG1hc',
#    'tweet_id': '1128692992552914944'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'user_id': 16298441,
#    'user_name': 'wint',
#    'tweet': 'where are my damn freaks.. where`s my nasty Posters. where are my fuckin doofuses',
#    'tweet_id': '1128691869712506881'},
#   'bert_result': {'identity_hate': 0.0072,
#    'insult': 0.9907,
#    'obscene': 0.9983,
#    'severe_toxic': 0.1988,
#    'threat': 0.0024,
#    'toxic': 0.9994}},
#  {'tweet': {'user_id': 2895499182,
#    'user_name': 'hardmaru',
#    'tweet': '“I miss the human interaction and sense of community that for several years the internet cafe provided. Now I too, like everyone else, scroll through my feed on my smartphone, head down on the train, not interacting in any way with the people around me.” https://t.co/OM7bFy3piI',
#    'tweet_id': '1128688750962270208'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'user_id': 3765572533,
#    'user_name': 'Dr Shawn Baker 🥩',
#    'tweet': 'RT @TuckerGoodrich: Here we go again! \n\nDiscussing this post:\n\nResponse to @garytaubes on Omega-6 Fats (Seed Oils) and Obesity\nhttps://t.co…',
#    'tweet_id': '1128688174547423234'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'user_id': 23909137,
#    'user_name': 'Larry Brown',
#    'tweet': 'RT @SteveDelSports: Jets fire GM Mike Maccagnan, make head coach Adam Gase their interim GM https://t.co/8oc0DCqFrk',
#    'tweet_id': '1128688061913751554'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0004}},
#  {'tweet': {'user_id': 858716964,
#    'user_name': 'PFTCommenter',
#    'tweet': 'RT @JaggerJames_: @PFTCommenter This is what Mike Greenberg has waited for his entire life',
#    'tweet_id': '1128687409535823873'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0006,
#    'obscene': 0.0012,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0041}},
#  {'tweet': {'user_id': 858716964,
#    'user_name': 'PFTCommenter',
#    'tweet': 'The Jet’s had a general manager???',
#    'tweet_id': '1128687139062001669'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'user_id': 1063559035,
#    'user_name': 'Sonic Pi',
#    'tweet': 'RT @BrechtDeMan: The official part of the Symposium on Audio Research and Practice in Belgium is closed by a spectacular immersive live cod…',
#    'tweet_id': '1128686847343910912'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'user_id': 2895499182,
#    'user_name': 'hardmaru',
#    'tweet': "RT @nlpmattg: Every conference I lean more and more towards just posting everything on arxiv. If I'm happy with the quality of the paper as…",
#    'tweet_id': '1128685125003141120'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'user_id': 625320955,
#    'user_name': 'Victor Mosquera',
#    'tweet': 'RT @visualatelier8: @victormosquerar’s Alluring Illustrations Exude Spiritual Peace &gt;&gt; https://t.co/tWRQ6hJOlP #art #illustration #creative…',
#    'tweet_id': '1128684895071555584'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'user_id': 216402879,
#    'user_name': 'Peter Ballerstedt',
#    'tweet': "Today's office, Day Two\n#NASFC @UCDavisWFC https://t.co/pKE2hM1hKi",
#    'tweet_id': '1128682125778046978'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0003,
#    'obscene': 0.0003,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0011}},
#  {'tweet': {'user_id': 3765572533,
#    'user_name': 'Dr Shawn Baker 🥩',
#    'tweet': 'RT @HarsellNancy: After many knee operations I could never bend my knees completely. Low carb eating has helped the pain and inflammation s…',
#    'tweet_id': '1128681587015471104'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0002,
#    'obscene': 0.0002,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0009}},
#  {'tweet': {'user_id': 3765572533,
#    'user_name': 'Dr Shawn Baker 🥩',
#    'tweet': 'RT @rolyatinator: @fjrtraveler @eallen83 @SBakerMD I defy the trend, I guess. Lefty lib here who eats nothing but meat and thinks vegans ar…',
#    'tweet_id': '1128680756404842499'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0001,
#    'toxic': 0.0002}},
#  {'tweet': {'user_id': 8496762,
#    'user_name': 'tylercowen',
#    'tweet': 'RT @jamesgibney: "When it comes to nuclear weapons, however, the arguments for pessimism only have to be true once." @tylercowen on why nuc…',
#    'tweet_id': '1128680684292325377'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0001,
#    'obscene': 0.0001,
#    'severe_toxic': 0.0001,
#    'threat': 0.0,
#    'toxic': 0.0003}},
#  {'tweet': {'user_id': 3765572533,
#    'user_name': 'Dr Shawn Baker 🥩',
#    'tweet': '😳 https://t.co/wKtsHCTmNe',
#    'tweet_id': '1128680667397496833'},
#   'bert_result': {'identity_hate': 0.0,
#    'insult': 0.0002,
#    'obscene': 0.0002,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.0005}},
#  {'tweet': {'user_id': 3765572533,
#    'user_name': 'Dr Shawn Baker 🥩',
#    'tweet': 'I’ll divide up a cow however 😜 https://t.co/sXbqxX9U2p',
#    'tweet_id': '1128680385636814849'},
#   'bert_result': {'identity_hate': 0.0055,
#    'insult': 0.007,
#    'obscene': 0.004,
#    'severe_toxic': 0.0034,
#    'threat': 0.012,
#    'toxic': 0.9896}},
#  {'tweet': {'user_id': 1536600704,
#    'user_name': 'Alex Griswold',
#    'tweet': 'Political cartoons are bad, folks! https://t.co/x0yCUUKVcE https://t.co/A4vv6mpXwf',
#    'tweet_id': '1128679017496838146'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0003,
#    'obscene': 0.0003,
#    'severe_toxic': 0.0,
#    'threat': 0.0,
#    'toxic': 0.001}},
#  {'tweet': {'user_id': 16023029,
#    'user_name': 'Joe Posnanski',
#    'tweet': 'Two hits. https://t.co/BmpcaOH4uO https://t.co/sFZp4YL8vt',
#    'tweet_id': '1128678922810527745'},
#   'bert_result': {'identity_hate': 0.0001,
#    'insult': 0.0008,
#    'obscene': 0.0007,
#    'severe_toxic': 0.0,
#    'threat': 0.0001,
#    'toxic': 0.0031}}]
