# %%
#!pip install trio
import json
import tweepy
import re
from collections import Counter
import time
from decouple import config
import trio
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize

# %%
TWITTER_AUTH = tweepy.OAuthHandler(config('TWITTER_CONSUMER_KEY'),config('TWITTER_CONSUMER_SECRET'))
TWITTER_AUTH.set_access_token(config('TWITTER_ACCESS_TOKEN'),config('TWITTER_ACCESS_TOKEN_SECRET'))
TWITTER = tweepy.API(TWITTER_AUTH)

# %%
start_api_check = TWITTER.rate_limit_status()
limits_alpha = json_normalize(start_api_check)

# %%
async def async_get_user_interactions(search, output, next_query, limit):
    """Crawls the targeted user's timeline and returns interactions.
    Args:
        `search`, string: The name of the user who's timeline to search.
        `output`, list of tuples: paired list of search & interaction targets. 
        `next_query`, list: a list of names to search on the next run. 
        `limit`, int: A flag to indicate how many results should be returned. 
    
    Functionality:
        Initialize search for the specific user.
        Get the user's tweets from their timeline. 
        Cycle through all the tweets' text and join it into a mega-string.
        Do some standardizing and replacing.
        Strip away everything except usernames, into a string. 
        Make a list of the counts, and take the top (X) most common people. 
        Creates a list of the `top` people. No duplicates 
        Tuple the results of the search & output together.
        Make search inputs for the next level of crawling.
    
    Returns:
        This function is async and has no return statement, rather it 
        instead updates the values of `output` and `next_query` extending
        the lists that were passed to it as args.
    """
    try:
        twitter_user = TWITTER.get_user(search)
        tweets = twitter_user.timeline(
                    count=200,
                    exclude_replies=False,
                    include_rts=True,
                    tweet_mode='extended'
        )
        b = [ i.full_text for i in tweets ]
        b = " ".join(b)
        b = b.lower()
        b = b.replace(search, "")
        out = re.findall(r'(?<=^|(?<=[^a-zA-Z0-9-_\.]))@([A-Za-z]+[A-Za-z0-9-_]+)',b)
        top = Counter(out).most_common(limit)

        if limit > 0:
            interactions = []
            for interaction_count in top:
                interactions += ([interaction_count[0]] * interaction_count[1])

            tweet_data = [(search, i) for i in interactions]
            output.extend(tweet_data)

            next_target_users = [person[0] for person in top]
            next_query.extend(next_target_users)

        elif limit == -1: 

            # Tuple the results of the search & output together.
            tweet_data = [(search, i) for i in out]
            output = output.extend(tweet_data)
            
    except tweepy.TweepError:
        print("tweepy.TweepError=")
        
    except:
        e = sys.exc_info()[0]
        print("Error: %s" % e)

# %%
async def interaction_chain():
    """Calls our async function & loops through it for each target user."""
    # input settings
    origin_user = ['bwinterrose']
    first_users = ['austen','paulg','justinkhan','tommycollison',"lambdaschool"]
    first_limit = 10 # -1 is no limit, anything above 1 sets limit.
    second_limit = 5 # -1 is no limit, anything above 1 sets limit. 
    third_limit = 5
    
    # init function variables
    level = 0
    data = []
    last = 2 # Set to number of levels. 
    start_time = time.time()
    last_time = time.time()
    next_users = first_users
    checked_users = origin_user

    # Updates the time for each loop.
    def funct_time(last, d, l):
        now = time.time()
        check_time = now - last
        print("\n\nLevel %s Completed\nLevel %s time to complete: %s." % (l, l, check_time))
        print("Level %s interactions found:", (l, len(d)))
        return now
    return next_users, checked_users, level 
    # Dedupe & Check user list for previous runs (no duplicated work). 
    def update_lists(x, y, l, l_n):
        # de-duplicate it.
        x = list(dict.fromkeys(x))
        # remove any users already searched
        for i in y:
            a = np.array(x)
            a = a[a != i]
            x = a.tolist()
        # add new values to the checked_list
        y += x
        # on first run.... 
        if l == 0:
            l += 1 
            print("----------Entering %sst level. Searching the following users:----------\n" % (l), x)
        # on other runs...
        else: 
            print("Level %s connections found:" % (l), len(x),"\n\n")
            if l_n > (l):
                l += 1
                print("---------Beginning Level %s - Searching the following users:\n" % (l), x) 
        return x, y, l
    
        
    # Level 1 Run.
    loop_num = 1
    async with trio.open_nursery() as nursery:
        for user in first_users:
            print("Loop # ", loop_num, " . Time so far:", time.time() - start_time)
            loop_num +=1
            nursery.start_soon(async_get_user_interactions, user, data, next_users, first_limit)
    
    last_time = funct_time(last_time, data, level)
    next_users, checked_users, level = update_lists(next_users, checked_users, level, last)


    # Level 2 Run.
    loop_num = 1
    async with trio.open_nursery() as nursery:
        for user in next_users:
            print("Loop # ", loop_num, " . Time so far:", time.time() - start_time)
            loop_num +=1
            nursery.start_soon(async_get_user_interactions, user, data, next_users, second_limit)
    
    last_time = funct_time(last_time, data, level)
    next_users, checked_users, level = update_lists(next_users, checked_users, level, last)


#     # Level 3 Run. Uncomment to run
#     loop_num = 1
#     async with trio.open_nursery() as nursery:
#         for user in next_users:
#             print("Loop # ", loop_num, " . Time so far:", time.time() - start_time)
#             loop_num +=1
#             nursery.start_soon(async_get_user_interactions, user, data, next_users, third_limit)
    
#     last_time = funct_time(last_time, data, level)
#     next_users, checked_users, level = update_lists(next_users, checked_users, level, last)
    
    print("Total time:", time.time() - start_time)
    print("Total Connections found:", (len(checked_users)-1))
    print("Total Overall Interactions found:", len(data))
    return data,next_users, checked_users, level

# %%
next_users, checked_users, level  = trio.run(interaction_chain)

# %%
next_users, checked_users, level
# Out:
# (['austen', 'paulg', 'justinkhan', 'tommycollison', 'lambdaschool'],
#  ['bwinterrose'],
#  0)

# %%
edges = Counter(data)

# %%
def update_lists(x, y, l, l_n):
        # de-duplicate it.
        x = list(dict.fromkeys(x))
        # remove any users already searched
        for i in y:
            a = np.array(x)
            a = a[a != i]
            x = a.tolist()
        # add new values to the checked_list
        y += x
        # on first run.... 
        if l == 0:
            l += 1 
            print("----------Entering %sst level. Searching the following users:----------\n" % (l), x)
        # on other runs...
        else: 
            print("Level %s connections found:" % (l), len(x),"\n\n")
            if l_n > (l):
                l += 1
                print("---------Beginning Level %s - Searching the following users:\n" % (l), x) 
        return x, y, l

# %%
x = next_users
y = checked_users
l = level

# %%
x = next_users
y = checked_users
l = level
print("X: ",len(x), x)
print("Y: ",len(y),y)
for i in y:
    a = np.array(x)
    a = a[a != i]
    x = a.tolist()
print("X: ", len(x), x)
print("Y: ",len(y),y)
# Out:
# X:  5 ['austen', 'paulg', 'justinkhan', 'tommycollison', 'lambdaschool']
# Y:  1 ['bwinterrose']
# X:  5 ['austen', 'paulg', 'justinkhan', 'tommycollison', 'lambdaschool']
# Y:  1 ['bwinterrose']

# %%
def remove_from_list(i,y):
    try:
        y.remove(i)
    except:
        pass

# %%
x1 = next_users
y1 = checked_users
for i in x1:
    remove_from_list(i,y1)

# %%
# Out:
# ['austen', 'paulg', 'justinkhan', 'tommycollison', 'lambdaschool']

# %%
data_c = Counter(data)

# %%
l_data_c = list(data_c)
data_v = data_c.values()

# %%
[{"source" : data_c[0]}]
# Out:
# Counter({('paulg', 'austen'): 11,
#          ('paulg', 'kevinsimler'): 9,
#          ('paulg', 'amasad'): 6,
#          ('paulg', 'webdevmason'): 6,
#          ('paulg', 'wrathofgnon'): 4,
#          ('paulg', 'atabarrok'): 4,
#          ('paulg', 'mckaywrigley'): 4,
#          ('paulg', 'lpolovets'): 4,
#          ('paulg', 'maxcroser'): 3,
#          ('paulg', 'stephansturges'): 3,
#          ('tommycollison', 'lambdaschool'): 36,
#          ('tommycollison', 'austen'): 33,
#          ('tommycollison', 'calebhicks'): 14,
#          ('tommycollison', 'trevmckendrick'): 11,
#          ('tommycollison', 'mitchellbwright'): 9,
#          ('tommycollison', 'ouraring'): 9,
#          ('tommycollison', 'ryanleehamblin'): 7,
#          ('tommycollison', 'mckaywrigley'): 7,
#          ('tommycollison', 'davecraige'): 7,
#          ('tommycollison', 'sunjieming'): 7,
#          ('lambdaschool', 'austen'): 62,
#          ('lambdaschool', 'tommycollison'): 9,
#          ('lambdaschool', 'dustint314'): 3,
#          ('lambdaschool', 'meaghanbarber9'): 3,
#          ('lambdaschool', 'ryanleehamblin'): 3,
#          ('lambdaschool', 'bri_theengineer'): 3,
#          ('lambdaschool', 'mispelledtoyota'): 2,
#          ('lambdaschool', 'mckaywrigley'): 2,
#          ('lambdaschool', 'danielgross'): 2,
#          ('lambdaschool', 'nandotheessen'): 2,
#          ('austen', 'lambdaschool'): 33,
#          ('austen', 'honestduane'): 10,
#          ('austen', 'rjnance'): 6,
#          ('austen', 'johnnewcastle2'): 5,
#          ('austen', 'slouischarles'): 5,
#          ('austen', 'bitcoinbingbong'): 5,
#          ('austen', 'ryanallred'): 4,
#          ('austen', 'ohmaar1'): 4,
#          ('austen', 'danoherrin'): 4,
#          ('austen', 'popeyethe13th'): 4,
#          ('johnnewcastle2', 'cernovich'): 12,
#          ('johnnewcastle2', 'joserosado'): 9,
#          ('johnnewcastle2', 'benjamingjw'): 7,
#          ('johnnewcastle2', 'primalpoly'): 6,
#          ('johnnewcastle2', 'austen'): 6,
#          ('wrathofgnon', 'based_jedi'): 5,
#          ('wrathofgnon', 'robertkwolek'): 4,
#          ('wrathofgnon', 'jimmylevendia'): 4,
#          ('wrathofgnon', 'yoruairi'): 3,
#          ('wrathofgnon', 'defendtradition'): 3,
#          ('maxcroser', 'ourworldindata'): 11,
#          ('maxcroser', 'hannahritchie02'): 11,
#          ('maxcroser', 'eortizospina'): 9,
#          ('maxcroser', 'jasonhickel'): 5,
#          ('maxcroser', 'dinapomeranz'): 4,
#          ('ryanleehamblin', 'lambdaschool'): 41,
#          ('ryanleehamblin', 'austen'): 16,
#          ('ryanleehamblin', 'joelbdenning'): 12,
#          ('ryanleehamblin', 'kyleshevlin'): 9,
#          ('ryanleehamblin', 'realsaltlake'): 9,
#          ('calebhicks', 'austen'): 12,
#          ('calebhicks', 'tommycollison'): 11,
#          ('calebhicks', 'lambdaschool'): 11,
#          ('calebhicks', 'trevmckendrick'): 9,
#          ('calebhicks', 'austenallred'): 9,
#          ('bri_theengineer', 'timurmeyster'): 9,
#          ('bri_theengineer', 'career_karma'): 5,
#          ('bri_theengineer', 'rubenharris'): 5,
#          ('bri_theengineer', 'tavachristian'): 5,
#          ('bri_theengineer', 'lambdaschool'): 4,
#          ('trevmckendrick', 'lambdaschool'): 12,
#          ('trevmckendrick', 'austen'): 9,
#          ('trevmckendrick', 'danmckendrick'): 7,
#          ('trevmckendrick', 'datarade'): 6,
#          ('trevmckendrick', 'patio11'): 5,
#          ('bitcoinbingbong', 'trylolli'): 26,
#          ('bitcoinbingbong', 'gethoneyminer'): 11,
#          ('bitcoinbingbong', 'lavie_encode'): 11,
#          ('bitcoinbingbong', 'treehouse'): 11,
#          ('bitcoinbingbong', 'martybent'): 10,
#          ('kevinsimler', 'drethelin'): 16,
#          ('kevinsimler', 'meaningness'): 13,
#          ('kevinsimler', 'robinhanson'): 7,
#          ('kevinsimler', 'artirkel'): 7,
#          ('kevinsimler', 'andrewsshi'): 6,
#          ('danielgross', 'pioneerdotapp'): 22,
#          ('danielgross', 'zoink'): 5,
#          ('danielgross', 'paulg'): 5,
#          ('danielgross', 'lambdaschool'): 4,
#          ('danielgross', 'austen'): 4,
#          ('honestduane', 'austen'): 17,
#          ('honestduane', 'hacks4pancakes'): 10,
#          ('honestduane', 'zachweiner'): 9,
#          ('honestduane', 'ladyred_6'): 7,
#          ('honestduane', 'swiftonsecurity'): 7,
#          ('nandotheessen', 'lambdaschool'): 34,
#          ('nandotheessen', 'austenallred'): 13,
#          ('nandotheessen', 'amyshackles'): 5,
#          ('nandotheessen', 'kentcdodds'): 4,
#          ('nandotheessen', 'proffeynman'): 3,
#          ('stephansturges', 'benedictevans'): 21,
#          ('stephansturges', 'paulg'): 8,
#          ('stephansturges', 'joerogan'): 8,
#          ('stephansturges', 'nntaleb'): 7,
#          ('stephansturges', 'amberbaldet'): 6,
#          ('lpolovets', 'sbyrnes'): 15,
#          ('lpolovets', 'dkimerling'): 11,
#          ('lpolovets', 'jjen_abel'): 7,
#          ('lpolovets', 'sarthakgh'): 6,
#          ('lpolovets', 'alibhamed'): 6,
#          ('popeyethe13th', 'taeluralexis'): 14,
#          ('popeyethe13th', 'pjausovec'): 14,
#          ('popeyethe13th', 'aoc'): 7,
#          ('popeyethe13th', 'levelsio'): 7,
#          ('popeyethe13th', 'calliph'): 6,
#          ('rjnance', 'cityblockcap'): 20,
#          ('rjnance', 'apompliano'): 15,
#          ('rjnance', 'austen'): 13,
#          ('rjnance', 'max_goldstein'): 12,
#          ('rjnance', 'markyusko'): 11,
#          ('amasad', 'replit'): 48,
#          ('amasad', 'kognise'): 7,
#          ('amasad', 'hazthewaz0001'): 6,
#          ('amasad', 'paulg'): 5,
#          ('amasad', 'nicklovescode'): 5,
#          ('slouischarles', 'naval'): 12,
#          ('slouischarles', 'paulg'): 9,
#          ('slouischarles', 'jesslivingston'): 8,
#          ('slouischarles', 'alexisohanian'): 8,
#          ('slouischarles', 'jamesclear'): 7,
#          ('ryanallred', 'austen'): 43,
#          ('ryanallred', 'lambdaschool'): 27,
#          ('ryanallred', 'calebhicks'): 7,
#          ('ryanallred', 'ryan_holdaway'): 5,
#          ('ryanallred', 'zimvc'): 4,
#          ('mispelledtoyota', 'lambdaschool'): 28,
#          ('mispelledtoyota', 'dan_abramov'): 26,
#          ('mispelledtoyota', 'coetry'): 13,
#          ('mispelledtoyota', 'samuelmachat'): 12,
#          ('mispelledtoyota', 'vgr'): 11,
#          ('atabarrok', 'leah_boustan'): 6,
#          ('atabarrok', 'causalinf'): 6,
#          ('atabarrok', 'dclingi'): 5,
#          ('atabarrok', 'noahpinion'): 3,
#          ('atabarrok', 'dandolfa'): 3,
#          ('mitchellbwright', 'lambdaschool'): 25,
#          ('mitchellbwright', 'scottcowley'): 23,
#          ('mitchellbwright', 'austen'): 18,
#          ('mitchellbwright', 'calebhicks'): 14,
#          ('mitchellbwright', 'trevmckendrick'): 10,
#          ('sunjieming', 'austenallred'): 83,
#          ('sunjieming', 'lambdaschool'): 45,
#          ('sunjieming', 'austen'): 14,
#          ('sunjieming', 'trevmckendrick'): 5,
#          ('sunjieming', 'ryanleehamblin'): 5,
#          ('ouraring', 'blnblueyetxn1'): 6,
#          ('ouraring', 'michaelakoenig'): 6,
#          ('ouraring', 'unrealdjing'): 5,
#          ('ouraring', 'philringsmuth'): 3,
#          ('ouraring', 'adriantombu'): 3,
#          ('meaghanbarber9', 'lambdaschool'): 5,
#          ('meaghanbarber9', 'austen'): 3,
#          ('meaghanbarber9', 'austenallred'): 3,
#          ('meaghanbarber9', 'tommycollison'): 1,
#          ('meaghanbarber9', 'patrickc'): 1,
#          ('davecraige', 'getmakerlog'): 8,
#          ('davecraige', 'figmadesign'): 8,
#          ('davecraige', 'dimarconicola'): 7,
#          ('davecraige', 'thestudio_io'): 7,
#          ('davecraige', 'alexintosh'): 6,
#          ('webdevmason', 'kevinsimler'): 19,
#          ('webdevmason', 'visakanv'): 11,
#          ('webdevmason', 'austen'): 11,
#          ('webdevmason', 'joefyhrceesay'): 11,
#          ('webdevmason', 'paulg'): 10,
#          ('dustint314', 'lambdaschool'): 66,
#          ('dustint314', 'dan_abramov'): 17,
#          ('dustint314', 'austen'): 10,
#          ('dustint314', 'reactjs'): 10,
#          ('dustint314', 'thebigknell'): 9,
#          ('ohmaar1', 'politibunny'): 9,
#          ('ohmaar1', 'gormogons'): 7,
#          ('ohmaar1', 'molratty'): 6,
#          ('ohmaar1', 'mdrache'): 6,
#          ('ohmaar1', 'gaypatriot'): 5,
#          ('mckaywrigley', 'austen'): 17,
#          ('mckaywrigley', 'lambdaschool'): 14,
#          ('mckaywrigley', 'bjc290'): 11,
#          ('mckaywrigley', 'rinnebach1'): 10,
#          ('mckaywrigley', 'jesslivingston'): 8,
#          ('danoherrin', 'mtracey'): 10,
#          ('danoherrin', 'cernovich'): 10,
#          ('danoherrin', 'puremichgirl'): 7,
#          ('danoherrin', 'barnes_law'): 7,
#          ('danoherrin', 'realdonaldtrump'): 7})
